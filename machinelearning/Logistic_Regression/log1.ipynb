# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,LogisticRegression

# %%
df=pd.read_csv('logistic_regression_dataset.csv')
df
# Out:
#                                  Review     Category    Rating
# 0         Not as expected, disappointed        Books  Negative
# 1         Fantastic! Highly recommended     Clothing  Negative
# 2        Great features and easy to use     Clothing  Negative
# 3             Horrible, do not buy this  Electronics  Positive
# 4         Fantastic! Highly recommended         Home  Positive
# ..                                  ...          ...       ...
# 95       Great features and easy to use         Toys  Negative
# 96  Excellent product, totally worth it         Home  Negative
# 97            Horrible, do not buy this        Books  Positive
# 98        Not as expected, disappointed  Electronics  Positive
# 99    Terrible product, not recommended        Books  Negative
#
# [100 rows x 3 columns]

# %%
df['Category'].unique()
# Out:
# array(['Books', 'Clothing', 'Electronics', 'Home', 'Toys'], dtype=object)

# %%
# df=df.drop('Review',axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label=LabelEncoder()
df['Category_label']=label.fit_transform(df['Category'])
X=df[['Category_label']]
y=df['Rating']

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,train_size=0.8,random_state=42)

# %%
model=LogisticRegression()
model.fit(Xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
ytest
# Out:
# 83    Negative
# 53    Positive
# 70    Negative
# 45    Negative
# 44    Negative
# 39    Positive
# 22    Positive
# 80    Positive
# 10    Positive
# 0     Negative
# 18    Positive
# 30    Negative
# 73    Negative
# 33    Positive
# 90    Negative
# 4     Positive
# 76    Positive
# 77    Positive
# 12    Negative
# 31    Positive
# Name: Rating, dtype: object

# %%
pred=model.predict(Xtest)
pred
# Out:
# array(['Positive', 'Positive', 'Positive', 'Negative', 'Negative',
#        'Positive', 'Negative', 'Positive', 'Positive', 'Negative',
#        'Negative', 'Positive', 'Positive', 'Negative', 'Negative',
#        'Positive', 'Positive', 'Positive', 'Positive', 'Negative'],
#       dtype=object)

# %%
model.score(Xtest,ytest)
# Out:
# 0.55

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest,pred)
# Out:
# 0.55

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer()
d=tfidf.fit_transform(df['Review'])

vector_x=d.toarray()
freature_name=tfidf.get_feature_names_out()
freature_name
# Out:
# array(['and', 'as', 'bad', 'buy', 'disappointed', 'do', 'easy', 'ever',
#        'excellent', 'expected', 'experience', 'fantastic', 'features',
#        'for', 'good', 'great', 'highly', 'horrible', 'it', 'loved',
#        'money', 'not', 'of', 'perfect', 'product', 'quality',
#        'recommended', 'terrible', 'this', 'to', 'totally', 'use', 'value',
#        'waste', 'worst', 'worth'], dtype=object)

# %%
vector_df=pd.DataFrame(vector_x,columns=freature_name)
vector_df
# Out:
#          and        as  bad       buy  disappointed        do     easy  ever  \
# 0   0.000000  0.533025  0.0  0.000000      0.533025  0.000000  0.00000   0.0
# 1   0.000000  0.000000  0.0  0.000000      0.000000  0.000000  0.00000   0.0
# 2   0.331473  0.000000  0.0  0.000000      0.000000  0.000000  0.42193   0.0
# 3   0.000000  0.000000  0.0  0.473489      0.000000  0.473489  0.00000   0.0
# 4   0.000000  0.000000  0.0  0.000000      0.000000  0.000000  0.00000   0.0
# ..       ...       ...  ...       ...           ...       ...      ...   ...
# 95  0.331473  0.000000  0.0  0.000000      0.000000  0.000000  0.42193   0.0
# 96  0.000000  0.000000  0.0  0.000000      0.000000  0.000000  0.00000   0.0
# 97  0.000000  0.000000  0.0  0.473489      0.000000  0.473489  0.00000   0.0
# 98  0.000000  0.533025  0.0  0.000000      0.533025  0.000000  0.00000   0.0
# 99  0.000000  0.000000  0.0  0.000000      0.000000  0.000000  0.00000   0.0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
vector_df['category_label']=label.fit_transform(df['Category'])
vector_df
# Out:
#          and        as  bad       buy  disappointed        do     easy  ever  \
# 0   0.000000  0.533025  0.0  0.000000      0.533025  0.000000  0.00000   0.0
# 1   0.000000  0.000000  0.0  0.000000      0.000000  0.000000  0.00000   0.0
# 2   0.331473  0.000000  0.0  0.000000      0.000000  0.000000  0.42193   0.0
# 3   0.000000  0.000000  0.0  0.473489      0.000000  0.473489  0.00000   0.0
# 4   0.000000  0.000000  0.0  0.000000      0.000000  0.000000  0.00000   0.0
# ..       ...       ...  ...       ...           ...       ...      ...   ...
# 95  0.331473  0.000000  0.0  0.000000      0.000000  0.000000  0.42193   0.0
# 96  0.000000  0.000000  0.0  0.000000      0.000000  0.000000  0.00000   0.0
# 97  0.000000  0.000000  0.0  0.473489      0.000000  0.473489  0.00000   0.0
# 98  0.000000  0.533025  0.0  0.000000      0.533025  0.000000  0.00000   0.0
# 99  0.000000  0.000000  0.0  0.000000      0.000000  0.000000  0.00000   0.0
#
# ...

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(vector_df,y,train_size=0.8,random_state=42)

# %% [markdown]
# model training

# %%
model=LogisticRegression()
model.fit(Xtrain,ytrain)
# Out:
# LogisticRegression()

# %% [markdown]
# model testing

# %%
pred=model.predict(Xtest)

# %% [markdown]
# model_Evaluation

# %%
from sklearn.metrics import confusion_matrix,precision_score,recall_score
confusion_matrix(ytest,pred)
# Out:
# array([[3, 6],
#        [4, 7]])

# %%
accuracy_score(ytest,pred)
# Out:
# 0.5

# %%
precision_score(ytest,pred,pos_label='Negative')
# Out:
# 0.42857142857142855

# %%
recall_score(ytest,pred,pos_label='Positive')
# Out:
# 0.6363636363636364
